# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader, TensorDataset

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Load dataset
df = pd.read_csv("sms.tsv", sep="\t", names=["label", "message"])

df.head()

# %%
import os 
print(os.listdir())
# Out:
# ['.anaconda', '.android', '.aws', '.conda', '.condarc', '.continuum', '.copilot', '.docker', '.dotnet', '.gitconfig', '.gradle', '.idea', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.librarymanager', '.m2', '.matplotlib', '.redhat', '.spyder-py3', '.templateengine', '.VirtualBox', '.virtual_documents', '.vscode', '3D Objects', 'ab (1).py', 'ab.py', 'Activity-2-CIS-470-SP25', 'Activity-3-CIS-470-SP25', 'adult.data', 'adult.names', 'adult.test', 'anaconda3', 'AndroidStudioProjects', 'app.css', 'AppData', 'Application Data', 'automobile.zip', 'car.c45-names', 'car.data', 'car.names', 'check.py', 'check1.py', 'CIS602_Project2_FINAL.ipynb', 'column_2C.dat', 'column_2C_weka.arff', 'column_3C.dat', 'column_3C_weka.arff', 'Contacts', 'Cookies', 'Crack', 'data', 'demo.py', 'Desktop', 'DHRUV ENGINEERS', 'dict1.py', 'dict2.py', 'dict3.py', 'dict4.py', 'dict5.py', 'Documents', 'Downloads', 'evenlst.py', 'fact.py', 'Favorites', 'firstprog.py', 'ftprog.py', 'grade (1).py', 'grade.py', 'heart.csv', 'heart.csv.csv', 'Heart_Disease_Classification_DL.ipynb', 'HM2-JUNIT', 'Homework 2.ipynb', 'HOMEWORK2', 'imports-85.data', 'imports-85.names', 'Index', 'IntelGraphicsProfiles', 'intersection.py', 'Jedi', 'JUNIT', 'lab Homework 3.ipynb', 'LabManual3_Encoding_Data (2).ipynb', 'LabManual_4_Train_a_Model(1).ipynb', 'lab_homework_1.ipynb', 'largest.py', 'largestnum.py', 'Linear_learner_mnist.ipynb', 'Links', 'Local Settings', 'misc', 'ML TASK 1.ipynb', 'mullst.py', 'Music', 'my code.py', 'My Documents', 'NCH Software Suite', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{7d451dd9-0eee-11f0-a59a-d5e6f3b1e9dd}.TM.blf', 'NTUSER.DAT{7d451dd9-0eee-11f0-a59a-d5e6f3b1e9dd}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{7d451dd9-0eee-11f0-a59a-d5e6f3b1e9dd}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'numberpattern.py', 'old.adult.names', 'OneDrive', 'package-lock.json', 'package.json', 'palindrome.py', 'PCAppStore', 'pg57.py', 'pg64_2.py', 'Pictures', 'PredictingSalePriceHouses_part1_v2 (2).ipynb', 'PrintHood', 'Project1_Heart_Diseas.ipynb', 'PycharmProjects', 'PythonCheatSheet(1).ipynb', 'Recent', 'rev.py', 'Saved Games', 'Searches', 'SendTo', 'SMS_Spam_LSTM_Project.ipynb', 'source', 'star.py', 'star1.py', 'Start Menu', 'sumdig.py', 'sumnatural.py', 'Supriya', 'Templates', 'test.csv', 'train.csv', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb', 'Videos', 'W9-Selenium', 'W9-Selenium-New', 'year.py']
